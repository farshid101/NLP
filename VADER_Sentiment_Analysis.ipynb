# %% [markdown]
# <a href="https://colab.research.google.com/github/farshid101/NLP/blob/main/VADER_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import library

# %%
import pandas as pd

# %% [markdown]
# ## Importing DataSet

# %%
df=pd.read_csv("MatroData emoji to text .csv")
df.head()
# Out:
#                                              comment  \
# 0    ধন্যবাদ ভাই।  এয়ারপোর্টে যেতে হলে উত্তরা কোন...
# 1    আশা করি সেপ্টেম্বরের প্রথম সপ্তাহে দেখতে পাব...
# 2    কোনটাই সহজ হবে না।  সবটাই এয়ারপোর্ট থেকে দূর...
# 3                                 Agargaon to Uttara
# 4  nice to see you in Bangladesh again. You reall...
#
#                                   Comment to English  \
# 0  thanks brother. If you want to go to the airpo...
# 1      hope to see the first week of September. With
# 2   will not be easy. All away from the airport, ...
# 3                                 Agargaon to Uttara
# 4  nice to see you in Bangladesh again. You reall...
#
#                                        Emoji to text
# 0   thanks brother. If you want to go to the airp...
# 1      hope to see the first week of September. With
# 2   will not be easy. All away from the airport, ...
# 3                                 Agargaon to Uttara
# 4  nice to see you in Bangladesh again. You reall...

# %% [markdown]
# ## Analyzing DataSet

# %%
df.value_counts()
# Out:
# comment                                                                                                                                                                                                                                                                                Comment to English                                                                                                                                                                                                                                                                     Emoji to text
# চালু মেট্রোরেল ষ্টেশনে টয়লেট ব্যবহারে টাকা নিচ্ছে                                                                                                                                                                                                                                     Taking money to use the toilet at Metrorail Station                                                                                                                                                                                                                                    Taking money to use the toilet at Metrorail Station                                                                                                                                                                                                                                      8
# ❤                                                                                                                                                                                                                                                                                      ❤                                                                                                                                                                                                                                                                                      red heart                                                                                                                                                                                                                                                                                4
# ❤❤❤❤❤                                                                                                                                                                                                                                                                                  ❤❤❤❤❤                                                                                                                                                                                                                                                                                  red heartred heartred heartred heartred heart                                                                                                                                                                                                                                            4
# পরিচালকে কেন প্রশ্ন করা হয় না যে পাবলিক টয়লেটে কেন টাকা নেয়া হয়?                                                                                                                                                                                                                       Why is the director question why the money is taken in the public toilet?                                                                                                                                                                                                              Why is the director question why the money is taken in the public toilet?                                                                                                                                                                                                                4
# Mr Triple R Army OP                                                                                                                                                                                                                                                                    Mr Triple R Army OP                                                                                                                                                                                                                                                                    Mr Triple R Army OP                                                                                                                                                                                                                                                                      4
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ..
# You are most welcome in Bangladesh. Firstly I would like to thanks you for briefing nicely about Dkaka Metro Rail as a Indian. Most of the Indian peoples ignore positive side  regarding the development of Bangladesh. Hope we will get more positive  videos  from The BongXplorer  You are most welcome in Bangladesh. Firstly I would like to thanks you for briefing nicely about Dkaka Metro Rail as a Indian. Most of the Indian peoples ignore positive side  regarding the development of Bangladesh. Hope we will get more positive  videos  from The BongXplorer  You are most welcome in Bangladesh. Firstly I would like to thanks you for briefing nicely about Dkaka Metro Rail as a Indian. Most of the Indian peoples ignore positive side  regarding the development of Bangladesh. Hope we will get more positive  videos  from The BongXplorer    1
# You are come again in Dhaka.In your last visiting time in Bangladesh I was see all video                                                                                                                                                                                               You are come again in Dhaka.In your last visiting time in Bangladesh I was see all video                                                                                                                                                                                               You are come again in Dhaka.In your last visiting time in Bangladesh I was see all video                                                                                                                                                                                                 1
# You are again in Dhaka! Very glad to see this.                                                                                                                                                                                                                                         You are again in Dhaka! Very glad to see this.                                                                                                                                                                                                                                         You are again in Dhaka! Very glad to see this.                                                                                                                                                                                                                                           1
# Yellow color will look posh                                                                                                                                                                                                                                                            Yellow color will look posh                                                                                                                                                                                                                                                            Yellow color will look posh                                                                                                                                                                                                                                                              1
# আলহামদুলিল্লাহ তাহলে কালকে অফিস শেষে বাড়ি ফিরব মেট্রো রেলে করে                                                                                                                                                                                                                        Alhamdulillah then returned home after the office at the end of the office                                                                                                                                                                                                             Alhamdulillah then returned home after the office at the end of the office                                                                                                                                                                                                               1
# Length: 2007, dtype: int64

# %%
df.count()
# Out:
# comment               2184
# Comment to English    2184
# Emoji to text         2184
# dtype: int64

# %% [markdown]
# ## Removing duplicating in pandas dataset

# %%
df_no_duplicates = df.drop_duplicates()

# %%
df_no_duplicates.sample(5)
# Out:
#                                                 comment  \
# 2001  রেললাইন আরো হোক বাংলাদেশ। 🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩💚💚💚💚💚👌...
# 1657                         নতুন প্রকল্প মানেই লুটপাট।
# 1704  পৃথিবীতে কোথাও নাকি দেখেনি ☝️🤣 ইউরোপে প্রায় স্...
# 1791                            বিচার করা দরকার চুরেদের
# 737                             Thank you Sheikh hasina
#
#                                      Comment to English  \
# 2001  The railway line is more Bangladesh. 🇧🇩🇧🇩🇧🇩🇧🇩🇧...
# 1657                     The new project means looting.
# 1704          We have never seen anywhere in the world.
# 1791                      The Churads need to be judged
# 737                             Thank you Sheikh hasina
#
#                                           Emoji to text
# 2001  The railway line is more Bangladesh. flag: Ban...
# 1657                     The new project means looting.
# 1704          We have never seen anywhere in the world.
# 1791                      The Churads need to be judged
# 737                             Thank you Sheikh hasina

# %%
df_no_duplicates.count()
# Out:
# comment               2007
# Comment to English    2007
# Emoji to text         2007
# dtype: int64

# %% [markdown]
# # Labeling DataSet

# %% [markdown]
# # VADER-Sentiment-Analysis
#
# For details:
# [GitHub Link](https://github.com/cjhutto/vaderSentiment?fbclid=IwAR1K1sEvL0VVJEqO5s3FeTTM5UILz5hH7n_tgSxdfX-DfMxGoKqfAnNIfz8https://)

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2023.7.22)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
# !pip install --upgrade vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2023.7.22)

# %% [markdown]
# ## Example Code of VaderSentiment

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
    #note: depending on how you installed (e.g., using source code download versus pip install), you may need to import like this:
    #from vaderSentiment import SentimentIntensityAnalyzer

# --- examples -------
sentences = ["VADER is smart, handsome, and funny.",  # positive sentence example
             "VADER is smart, handsome, and funny!",  # punctuation emphasis handled correctly (sentiment intensity adjusted)
             "VADER is very smart, handsome, and funny.", # booster words handled correctly (sentiment intensity adjusted)
             "VADER is VERY SMART, handsome, and FUNNY.",  # emphasis for ALLCAPS handled
             "VADER is VERY SMART, handsome, and FUNNY!!!", # combination of signals - VADER appropriately adjusts intensity
             "VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!!", # booster words & punctuation make this close to ceiling for score
             "VADER is not smart, handsome, nor funny.",  # negation sentence example
             "The book was good.",  # positive sentence
             "At least it isn't a horrible book.",  # negated negative sentence with contraction
             "The book was only kind of good.", # qualified positive sentence is handled correctly (intensity adjusted)
             "The plot was good, but the characters are uncompelling and the dialog is not great.", # mixed negation sentence
             "Today SUX!",  # negative slang with capitalization emphasis
             "Today only kinda sux! But I'll get by, lol", # mixed sentiment example with slang and constrastive conjunction "but"
             "Make sure you :) or :D today!",  # emoticons handled
             "Catch utf-8 emoji such as such as 💘 and 💋 and 😁",  # emojis handled
             "Not bad at all"  # Capitalized negation
             ]

analyzer = SentimentIntensityAnalyzer()
for sentence in sentences:
    vs = analyzer.polarity_scores(sentence)
    print("{:-<65} {}".format(sentence, str(vs)))
# Out:
# VADER is smart, handsome, and funny.----------------------------- {'neg': 0.0, 'neu': 0.254, 'pos': 0.746, 'compound': 0.8316}
# VADER is smart, handsome, and funny!----------------------------- {'neg': 0.0, 'neu': 0.248, 'pos': 0.752, 'compound': 0.8439}
# VADER is very smart, handsome, and funny.------------------------ {'neg': 0.0, 'neu': 0.299, 'pos': 0.701, 'compound': 0.8545}
# VADER is VERY SMART, handsome, and FUNNY.------------------------ {'neg': 0.0, 'neu': 0.246, 'pos': 0.754, 'compound': 0.9227}
# VADER is VERY SMART, handsome, and FUNNY!!!---------------------- {'neg': 0.0, 'neu': 0.233, 'pos': 0.767, 'compound': 0.9342}
# VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!!--------- {'neg': 0.0, 'neu': 0.294, 'pos': 0.706, 'compound': 0.9469}
# VADER is not smart, handsome, nor funny.------------------------- {'neg': 0.646, 'neu': 0.354, 'pos': 0.0, 'compound': -0.7424}
# The book was good.----------------------------------------------- {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# At least it isn't a horrible book.------------------------------- {'neg': 0.0, 'neu': 0.678, 'pos': 0.322, 'compound': 0.431}
# The book was only kind of good.---------------------------------- {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.3832}
# The plot was good, but the characters are uncompelling and the dialog is not great. {'neg': 0.327, 'neu': 0.579, 'pos': 0.094, 'compound': -0.7042}
# Today SUX!------------------------------------------------------- {'neg': 0.779, 'neu': 0.221, 'pos': 0.0, 'compound': -0.5461}
# Today only kinda sux! But I'll get by, lol----------------------- {'neg': 0.127, 'neu': 0.556, 'pos': 0.317, 'compound': 0.5249}
# Make sure you :) or :D today!------------------------------------ {'neg': 0.0, 'neu': 0.294, 'pos': 0.706, 'compound': 0.8633}
# Catch utf-8 emoji such as such as 💘 and 💋 and 😁------------------ {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.875}
# Not bad at all--------------------------------------------------- {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.431}

# %% [markdown]
# ## Applying the Code

# %%
df_text=df_no_duplicates['Emoji to text']

#df_text = pd.DataFrame(df_text)
df_text.sample(5)
# Out:
# 884     We love this couple who visited us before and ...
# 660                    Purbachal Smart City Er Update and
# 1640    Thanks dear journalist brother for promoting t...
# 1706                       All countries on earth have AC
# 317                                         Dubai te ashe
# Name: Emoji to text, dtype: object

# %%
df_text.head()
# Out:
# 0     thanks brother. If you want to go to the airp...
# 1        hope to see the first week of September. With
# 2     will not be easy. All away from the airport, ...
# 3                                   Agargaon to Uttara
# 4    nice to see you in Bangladesh again. You reall...
# Name: Emoji to text, dtype: object

# %% [markdown]
# ## Making a Function

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.8.0

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd

def analyze_sentiment(list):
  """
  this function will take a list . Predict the label .
  """
  analyzer = SentimentIntensityAnalyzer()
  for sentence in df_text:
    vs = analyzer.polarity_scores(sentence)
    print("{:-<65} {}".format(sentence, str(vs)))
  return vs

# %%
df_no_duplicates.head()
# Out:
#                                              comment  \
# 0    ধন্যবাদ ভাই।  এয়ারপোর্টে যেতে হলে উত্তরা কোন...
# 1    আশা করি সেপ্টেম্বরের প্রথম সপ্তাহে দেখতে পাব...
# 2    কোনটাই সহজ হবে না।  সবটাই এয়ারপোর্ট থেকে দূর...
# 3                                 Agargaon to Uttara
# 4  nice to see you in Bangladesh again. You reall...
#
#                                   Comment to English  \
# 0  thanks brother. If you want to go to the airpo...
# 1      hope to see the first week of September. With
# 2   will not be easy. All away from the airport, ...
# 3                                 Agargaon to Uttara
# 4  nice to see you in Bangladesh again. You reall...
#
#                                        Emoji to text
# 0   thanks brother. If you want to go to the airp...
# 1      hope to see the first week of September. With
# 2   will not be easy. All away from the airport, ...
# 3                                 Agargaon to Uttara
# 4  nice to see you in Bangladesh again. You reall...

# %%
len(df_text)
# Out:
# 2008

# %%
predict_df=df_no_duplicates.copy()
predict_df.sample(5)
# Out:
#                                                 comment  \
# 1113  আমার দেশের মেট্রোরেল কলকাতার ভাইয়ের ক্যামেরায় ...
# 615                                     Nice good video
# 2017                              শুক্রবার বন্ধ না দিয়ে
# 889                  We'll be really benefitted by this
# 1954                    মেট্রোরেল। বাংলার।গর্ব জয়।বাংলা
#
#                                      Comment to English  \
# 1113  It was great to see the brother of Kolkata's b...
# 615                                     Nice good video
# 2017                                 Without off Friday
# 889                  We'll be really benefitted by this
# 1954                                  Metrorail. Bengal
#
#                                           Emoji to text
# 1113  It was great to see the brother of Kolkata's b...
# 615                                     Nice good video
# 2017                                 Without off Friday
# 889                  We'll be really benefitted by this
# 1954                                  Metrorail. Bengal

# %% [markdown]
# ```
# # This is formatted as code
# analyzer = SentimentIntensityAnalyzer()
# for sentence in df_text:
#     vs = analyzer.polarity_scores(sentence)
#     print("{:-<65} {}".format(sentence, str(vs)))
#
# ```

# %%
df_text
# Out:
# 0        thanks brother. If you want to go to the airp...
# 1           hope to see the first week of September. With
# 2        will not be easy. All away from the airport, ...
# 3                                      Agargaon to Uttara
# 4       nice to see you in Bangladesh again. You reall...
#                               ...
# 2179    This is a novel that you don't go underground,...
# 2180    Excuse me from Japan! Congratulations on the l...
# 2181    I am delighted that Japanese railway technolog...
# 2182    Seems to be recent. Hope the rest can be done ...
# 2183    It is amazing that a policeman has a rifle at ...
# Name: Emoji to text, Length: 2007, dtype: object

# %%
analyzer = SentimentIntensityAnalyzer()
for  row in df_text:
  vs = analyzer.polarity_scores(sentence)
  predict_df['prediction']=str(vs)

# %%
predict_df['prediction'].sample(5)
# Out:
# 1262    {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 1081    {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 905     {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 1350    {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 757     {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# Name: prediction, dtype: object

# %%
predict_df.head()
# Out:
#                                              comment  \
# 0    ধন্যবাদ ভাই।  এয়ারপোর্টে যেতে হলে উত্তরা কোন...
# 1    আশা করি সেপ্টেম্বরের প্রথম সপ্তাহে দেখতে পাব...
# 2    কোনটাই সহজ হবে না।  সবটাই এয়ারপোর্ট থেকে দূর...
# 3                                 Agargaon to Uttara
# 4  nice to see you in Bangladesh again. You reall...
#
#                                   Comment to English  \
# 0  thanks brother. If you want to go to the airpo...
# 1      hope to see the first week of September. With
# 2   will not be easy. All away from the airport, ...
# 3                                 Agargaon to Uttara
# 4  nice to see you in Bangladesh again. You reall...
#
#                                        Emoji to text  \
# 0   thanks brother. If you want to go to the airp...
# 1      hope to see the first week of September. With
# 2   will not be easy. All away from the airport, ...
# 3                                 Agargaon to Uttara
# 4  nice to see you in Bangladesh again. You reall...
#
#                                           prediction
# 0  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 1  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 2  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 3  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 4  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...

# %% [markdown]
# # Analyzing the prediction columns

# %%
df_a= predict_df["prediction"]
df_a.sample(10)
# Out:
# 26      {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 959     {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 1896    {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 1120    {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 1917    {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 1265    {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 497     {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 1971    {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 208     {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# 2121    {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...
# Name: prediction, dtype: object

# %%
df_a.value_counts()
# Out:
# {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'compound': 0.6239}    2007
# Name: prediction, dtype: int64

# %%
result_list = []

for index, sentiment_str in df_a.items():
    sentiment_dict = eval(sentiment_str)  # Convert the string to a dictionary
    max_sentiment_label = max(sentiment_dict, key=sentiment_dict.get)
    max_sentiment_value = sentiment_dict[max_sentiment_label]
    predict_df["max_sentiment_label"]=max_sentiment_label
    predict_df["max_sentiment_value"]=max_sentiment_value

    result_list.append((max_sentiment_label, max_sentiment_value))

# Create a DataFrame from the result_list
result_df = pd.DataFrame(result_list, columns=["Max_Sentiment_Label", "Max_Sentiment_Value"])

# Display the DataFrame
print(result_df)
# Out:
#      Max_Sentiment_Label  Max_Sentiment_Value
# 0                    neu                0.746
# 1                    neu                0.746
# 2                    neu                0.746
# 3                    neu                0.746
# 4                    neu                0.746
# ...                  ...                  ...
# 2002                 neu                0.746
# 2003                 neu                0.746
# 2004                 neu                0.746
# 2005                 neu                0.746
# 2006                 neu                0.746
#
# [2007 rows x 2 columns]

# %%
result_df.value_counts()
# Out:
# Max_Sentiment_Label  Max_Sentiment_Value
# neu                  0.746                  2007
# dtype: int64

# %%
predict_df
# Out:
#                                                 comment  \
# 0       ধন্যবাদ ভাই।  এয়ারপোর্টে যেতে হলে উত্তরা কোন...
# 1       আশা করি সেপ্টেম্বরের প্রথম সপ্তাহে দেখতে পাব...
# 2       কোনটাই সহজ হবে না।  সবটাই এয়ারপোর্ট থেকে দূর...
# 3                                    Agargaon to Uttara
# 4     nice to see you in Bangladesh again. You reall...
# ...                                                 ...
# 2179  এটি একটি উপন্যাস যে আপনি ভূগর্ভস্থ যান না যদিও...
# 2180  জাপান থেকে আমাকে মাফ করবেন! ঢাকা মেট্রো চালুর ...
# 2181  আমি অত্যন্ত আনন্দিত যে জাপানি রেলওয়ে প্রযুক্ত...
# 2182  সাম্প্রতিক বলে মনে হচ্ছে। আশা করি বাকিটাও তাড়...
# 2183  এটা আশ্চর্যজনক যে একটি ট্রেন স্টেশনে একজন পুলি...
#
#                                      Comment to English  \
# 0     thanks brother. If you want to go to the airpo...
# 1         hope to see the first week of September. With
# 2      will not be easy. All away from the airport, ...
# 3                                    Agargaon to Uttara
# 4     nice to see you in Bangladesh again. You reall...
# ...                                                 ...
# 2179  This is a novel that you don't go underground,...
# 2180  Excuse me from Japan! Congratulations on the l...
# 2181  I am delighted that Japanese railway technolog...
# 2182  Seems to be recent. Hope the rest can be done ...
# 2183  It is amazing that a policeman has a rifle at ...
#
#                                           Emoji to text  \
# 0      thanks brother. If you want to go to the airp...
# 1         hope to see the first week of September. With
# 2      will not be easy. All away from the airport, ...
# 3                                    Agargaon to Uttara
# 4     nice to see you in Bangladesh again. You reall...
# ...                                                 ...
# 2179  This is a novel that you don't go underground,...
# 2180  Excuse me from Japan! Congratulations on the l...
# 2181  I am delighted that Japanese railway technolog...
# 2182  Seems to be recent. Hope the rest can be done ...
# 2183  It is amazing that a policeman has a rifle at ...
#
#                                              prediction max_sentiment_label  \
# 0     {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...                 neu
# 1     {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...                 neu
# 2     {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...                 neu
# 3     {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...                 neu
# 4     {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...                 neu
# ...                                                 ...                 ...
# 2179  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...                 neu
# 2180  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...                 neu
# 2181  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...                 neu
# 2182  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...                 neu
# 2183  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...                 neu
#
#       max_sentiment_value
# 0                   0.746
# 1                   0.746
# 2                   0.746
# 3                   0.746
# 4                   0.746
# ...                   ...
# 2179                0.746
# 2180                0.746
# 2181                0.746
# 2182                0.746
# 2183                0.746
#
# [2007 rows x 6 columns]

# %%
from google.colab import files



# Save the DataFrame to a CSV file
df.to_csv('MatroData predict label.csv', index=False)  # Replace 'my_dataframe.csv' with your desired file name

# Download the CSV file
files.download('MatroData predict label.csv')
